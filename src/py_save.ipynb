# %%
import numpy as np
import pyspedas
import pytplot
import datetime as dt

# %%
tr = ['2018-10-08', '2018-10-09']

# %%
from pyspedas.erg import orb
orb(trange=tr)
# Out:
# 02-Nov-23 21:21:07: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/orb/def/2018/
# 02-Nov-23 21:21:08: File is current: erg_data/satellite/erg/orb/def/2018/erg_orb_l2_20181008_v03.cdf
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Level-2 orbit data
#
# Information about ERG orbit
#
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
#
# Contact: erg-sc-core at isee.nagoya-u.ac.jp
# **************************************************************************
# ['erg_orb_l2_pos_llr',
#  'erg_orb_l2_pos_gse',
#  'erg_orb_l2_pos_gsm',
#  'erg_orb_l2_pos_sm',
#  'erg_orb_l2_pos_rmlatmlt',
#  'erg_orb_l2_pos_eq',
#  'erg_orb_l2_pos_iono_north',
#  'erg_orb_l2_pos_iono_south',
#  'erg_orb_l2_pos_blocal',
#  'erg_orb_l2_pos_blocal_mag',
#  'erg_orb_l2_pos_beq',
#  'erg_orb_l2_pos_beq_mag',
#  'erg_orb_l2_pos_Lm',
#  'erg_orb_l2_vel_gse',
#  'erg_orb_l2_vel_gsm',
#  'erg_orb_l2_vel_sm',
#  'erg_orb_l2_spn_num',
#  'erg_orb_l2_man_prep_flag',
#  'erg_orb_l2_man_on_flag',
#  'erg_orb_l2_eclipse_flag']

# %%
# 軌道データの読み込みとIGRFモデルベースの特性周波数の変数づくり
datay = pytplot.data_quants['erg_orb_l2_pos_blocal_mag']
fce = datay / 1e9 * 1.6 * 1e-19 / (9.1093 * 1e-31) /2.0 / np.pi / 1000.0 # kHz
fce_05 = fce / 2.0 # kHz
fce_01 = fce / 10.0 # kHz

fch = fce / 1837. * 1000. # Hz

pytplot.store_data('fce', data={'x': datay['time'], 'y': fce})
pytplot.store_data('fce_05', data={'x': datay['time'], 'y': fce_05})
pytplot.store_data('fce_01', data={'x': datay['time'], 'y': fce_01})
pytplot.store_data('fch', data={'x': datay['time'], 'y': fch})
pytplot.options('fce', opt_dict={'color': 'beige', 'thick':2})
pytplot.options('fce_05', opt_dict={'color': 'magenta', 'thick':2, 'linestyle':'--'})
pytplot.options('fce_01', opt_dict={'color': 'grey', 'thick':2, 'linestyle':'--'})
pytplot.options('fch', opt_dict={'color': 'yellow', 'thick':2, 'linestyle':'--'})

# %%
# 

from pyspedas.erg import pwe_hfa
pwe_hfa(trange=tr, mode='low')
pwe_hfa(trange=tr, mode='monit')
pwe_hfa(trange=tr, mode='high')
# Out:
# 02-Nov-23 21:21:08: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/hfa/l2/spec/low/2018/10/
# 02-Nov-23 21:21:09: File is current: erg_data/satellite/erg/pwe/hfa/l2/spec/low/2018/10/erg_pwe_hfa_l2_spec_low_20181008_v01_02.cdf
# 02-Nov-23 21:21:11: erg_pwe_hfa_l2_low_spectra_eu contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:21:11: erg_pwe_hfa_l2_low_spectra_ev contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:21:11: erg_pwe_hfa_l2_low_spectra_er contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:21:11: erg_pwe_hfa_l2_low_spectra_el contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:21:11: erg_pwe_hfa_l2_low_spectra_e_ar contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:21:11: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_low_spectra_eu_ev
# 02-Nov-23 21:21:11: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_low_spectra_eu_ev
# 02-Nov-23 21:21:11: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_low_spectra_eu_ev
# 02-Nov-23 21:21:11: erg_pwe_hfa_l2_low_spectra_eu_ev does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:21:11: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_low_spectra_eu_bg
# 02-Nov-23 21:21:11: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_low_spectra_eu_bg
# 02-Nov-23 21:21:11: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_low_spectra_eu_bg
# 02-Nov-23 21:21:12: erg_pwe_hfa_l2_low_spectra_eu_bg does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:21:12: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_low_spectra_ev_bg
# 02-Nov-23 21:21:12: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_low_spectra_ev_bg
# 02-Nov-23 21:21:12: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_low_spectra_ev_bg
# 02-Nov-23 21:21:12: erg_pwe_hfa_l2_low_spectra_ev_bg does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:21:12: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/hfa/l2/spec/monit/2018/10/
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Electric Field Data (HFA) Level 2 spectrum data
#
# Information about ERG PWE HFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/HFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Hfa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 02-Nov-23 21:21:12: File is current: erg_data/satellite/erg/pwe/hfa/l2/spec/monit/2018/10/erg_pwe_hfa_l2_spec_monit_20181008_v01_02.cdf
# 02-Nov-23 21:21:12: erg_pwe_hfa_l2_monit_spectra_eu contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:21:12: erg_pwe_hfa_l2_monit_spectra_ev contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:21:12: erg_pwe_hfa_l2_monit_spectra_e_ar contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:21:12: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_monit_spectra_eu_ev
# 02-Nov-23 21:21:12: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_monit_spectra_eu_ev
# 02-Nov-23 21:21:12: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_monit_spectra_eu_ev
# 02-Nov-23 21:21:12: erg_pwe_hfa_l2_monit_spectra_eu_ev does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:21:12: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_monit_spectra_eu_bg
# 02-Nov-23 21:21:12: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_monit_spectra_eu_bg
# 02-Nov-23 21:21:12: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_monit_spectra_eu_bg
# 02-Nov-23 21:21:12: erg_pwe_hfa_l2_monit_spectra_eu_bg does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:21:12: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_monit_spectra_ev_bg
# 02-Nov-23 21:21:12: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_monit_spectra_ev_bg
# 02-Nov-23 21:21:12: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_monit_spectra_ev_bg
# 02-Nov-23 21:21:12: erg_pwe_hfa_l2_monit_spectra_ev_bg does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:21:12: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/hfa/l2/spec/high/2018/10/
# 02-Nov-23 21:21:12: File is current: erg_data/satellite/erg/pwe/hfa/l2/spec/high/2018/10/erg_pwe_hfa_l2_spec_high_20181008_v01_02.cdf
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Electric Field Data (HFA) Level 2 spectrum data
#
# Information about ERG PWE HFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/HFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Hfa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 02-Nov-23 21:21:20: erg_pwe_hfa_l2_high_spectra_eu contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:21:20: erg_pwe_hfa_l2_high_spectra_ev contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:21:20: erg_pwe_hfa_l2_high_spectra_er contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:21:20: erg_pwe_hfa_l2_high_spectra_el contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:21:21: erg_pwe_hfa_l2_high_spectra_e_mix contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:21:21: erg_pwe_hfa_l2_high_spectra_e_ar contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:21:21: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_high_spectra_eu_ev
# 02-Nov-23 21:21:21: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_high_spectra_eu_ev
# 02-Nov-23 21:21:21: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_high_spectra_eu_ev
# 02-Nov-23 21:21:21: erg_pwe_hfa_l2_high_spectra_eu_ev does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:21:21: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_high_spectra_eu_bg
# 02-Nov-23 21:21:21: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_high_spectra_eu_bg
# 02-Nov-23 21:21:21: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_high_spectra_eu_bg
# 02-Nov-23 21:21:21: erg_pwe_hfa_l2_high_spectra_eu_bg does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:21:21: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_high_spectra_ev_bg
# 02-Nov-23 21:21:21: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_high_spectra_ev_bg
# 02-Nov-23 21:21:21: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_high_spectra_ev_bg
# 02-Nov-23 21:21:21: erg_pwe_hfa_l2_high_spectra_ev_bg does not contain coordinates for spectrogram plotting.  Continuing...
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Electric Field Data (HFA) Level 2 spectrum data
#
# Information about ERG PWE HFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/HFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Hfa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# ['erg_pwe_hfa_l2_high_Epoch',
#  'erg_pwe_hfa_l2_high_spectra_eu',
#  'erg_pwe_hfa_l2_high_spectra_ev',
#  'erg_pwe_hfa_l2_high_spectra_bgamma',
#  'erg_pwe_hfa_l2_high_spectra_esum',
#  'erg_pwe_hfa_l2_high_spectra_er',
#  'erg_pwe_hfa_l2_high_spectra_el',
#  'erg_pwe_hfa_l2_high_spectra_e_mix',
#  'erg_pwe_hfa_l2_high_spectra_e_ar',
#  'erg_pwe_hfa_l2_high_spectra_eu_ev',
#  'erg_pwe_hfa_l2_high_spectra_eu_bg',
#  'erg_pwe_hfa_l2_high_spectra_ev_bg',
#  'erg_pwe_hfa_l2_high_quality_flag']

# %%
timelow = pytplot.data_quants['erg_pwe_hfa_l2_low_spectra_e_mix']['time']
low = pytplot.data_quants['erg_pwe_hfa_l2_low_spectra_e_mix']
timemonit = pytplot.data_quants['erg_pwe_hfa_l2_monit_spectra_e_mix']['time']
monit = pytplot.data_quants['erg_pwe_hfa_l2_monit_spectra_e_mix']
timelow = timelow.to_numpy()
timemonit = timemonit.to_numpy()
len_v_dim = len(pytplot.data_quants['erg_pwe_hfa_l2_monit_spectra_e_mix']['v_dim'])
v_dim = pytplot.data_quants['erg_pwe_hfa_l2_monit_spectra_e_mix']['v_dim']
timemerged = np.sort(np.hstack((timelow, timemonit)))
len_v_dim = len(pytplot.data_quants['erg_pwe_hfa_l2_monit_spectra_e_mix']['v_dim'])
merged_data = np.zeros((len(timemerged), len_v_dim))

# 'low' データを 'timelow' に対応する位置にコピー
for i, timestamp in enumerate(timelow):
    index = np.where(timemerged == timestamp)[0]
    merged_data[index] = low[i]

# 'omit' データを 'timeomit' に対応する位置にコピー
for i, timestamp in enumerate(timemonit):
    #mask = timemerged == timestamp  # 'timestamp' と一致する場所を示すブール値の配列を作成
    index = np.where(timemerged == timestamp)[0]
    merged_data[index] = monit[i]
pytplot.store_data('merged', data={'x': timemerged, 'y': merged_data, 'v': v_dim})
pytplot.options('merged', opt_dict={'zlog': True, 'ylog': True, 'yrange': [1e-0, 1e4], 'zrange': [1e-10, 1e-3], 'spec': True})

# %%
from pyspedas.erg import pwe_ofa
pwe_ofa(trange=tr)
# Out:
# 02-Nov-23 21:21:23: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2018/10/
# 02-Nov-23 21:21:23: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2018/10/erg_pwe_ofa_l2_spec_20181008_v02_03.cdf
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/OFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Ofa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# ['erg_pwe_ofa_l2_spec_epoch_e132',
#  'erg_pwe_ofa_l2_spec_E_spectra_132',
#  'erg_pwe_ofa_l2_spec_quality_flag_e132',
#  'erg_pwe_ofa_l2_spec_epoch_b132',
#  'erg_pwe_ofa_l2_spec_B_spectra_132',
#  'erg_pwe_ofa_l2_spec_quality_flag_b132']

# %%
pytplot.options( 'erg_pwe_ofa_l2_spec_E_spectra_132' , opt_dict={'zlog': True, 'ylog': True, 'zrange': [1e-9, 1e-2], 'spec': True})
pytplot.options( 'erg_pwe_ofa_l2_spec_B_spectra_132' , opt_dict={'zlog': True, 'ylog': True, 'zrange': [1e-4, 1e2], 'spec': True})

# %%
from pyspedas.erg import pwe_efd
pwe_efd(trange=tr, datatype='spec')
pwe_efd(trange=tr, datatype='E_spin')
pwe_efd(trange=tr, datatype='pot')
# Out:
# 02-Nov-23 21:21:25: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/efd/l2/spec/2018/10/
# 02-Nov-23 21:21:26: File is current: erg_data/satellite/erg/pwe/efd/l2/spec/2018/10/erg_pwe_efd_l2_spec_20181008_v02_02.cdf
# 02-Nov-23 21:21:26: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/efd/l2/E_spin/2018/10/
# 02-Nov-23 21:21:26: File is current: erg_data/satellite/erg/pwe/efd/l2/E_spin/2018/10/erg_pwe_efd_l2_E_spin_20181008_v05_01.cdf
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Electric Field Data (EFD) Level 2 spectrum data
#
# Information about ERG PWE EFD
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/EFD: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Efd
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 02-Nov-23 21:21:27: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/efd/l2/pot/2018/10/
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Electric Field Detector (EFD) Level 2 spectrum data
#
# Information about ERG PWE EFD
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/EFD: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Efd
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 02-Nov-23 21:21:27: File is current: erg_data/satellite/erg/pwe/efd/l2/pot/2018/10/erg_pwe_efd_l2_pot_20181008_v03_01.cdf
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Electric Field Detector (EFD) Level 2 potential data
#
# Information about ERG PWE EFD
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/EFD: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Efd
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# ['erg_pwe_efd_l2_pot_quality_flag',
#  'erg_pwe_efd_l2_pot_Vu1',
#  'erg_pwe_efd_l2_pot_Vv1',
#  'erg_pwe_efd_l2_pot_Vu2',
#  'erg_pwe_efd_l2_pot_Vv2',
#  'erg_pwe_efd_l2_pot_Vave']

# %%
Eux = pytplot.data_quants['erg_pwe_efd_l2_E_spin_Eu_dsi'][:,0]
Euy = pytplot.data_quants['erg_pwe_efd_l2_E_spin_Eu_dsi'][:,1]
Evx = pytplot.data_quants['erg_pwe_efd_l2_E_spin_Ev_dsi'][:,0]
Evy = pytplot.data_quants['erg_pwe_efd_l2_E_spin_Ev_dsi'][:,1]
Euoff = pytplot.data_quants['erg_pwe_efd_l2_E_spin_Eu_offset']
Evoff = pytplot.data_quants['erg_pwe_efd_l2_E_spin_Ev_offset']
EuEvoff = np.zeros((len(Euoff), 2))
EuEvoff[:,0] = Euoff
EuEvoff[:,1] = Evoff
Eu = np.sqrt(Eux**2 + Euy**2)
Ev = np.sqrt(Evx**2 + Evy**2)
EuEv = np.zeros((len(Eu), 2))
EuEv[:,0] = Eu
EuEv[:,1] = Ev

# %%
pytplot.store_data('EuEv', data={'x': pytplot.data_quants['erg_pwe_efd_l2_E_spin_Eu_dsi']['time'], 'y': EuEv})
pytplot.store_data('EuEvoff', data={'x': pytplot.data_quants['erg_pwe_efd_l2_E_spin_Eu_dsi']['time'], 'y': EuEvoff})
pytplot.options('EuEv', opt_dict={'legend_names': ['u', 'v'], 'yrange': [ 0, 10], 'ytitle':'EFD amplitude', 'ysubtitle':'[mV/m]'})
pytplot.options('EuEvoff', opt_dict={'legend_names': ['u', 'v'], 'yrange': [ -10,10], 'ytitle':'EFD offset', 'ysubtitle':'[mV/m]'})

# %%
pytplot.options('erg_pwe_efd_l2_spec_spectra', opt_dict={'zlog': True, 'ylog': True, 'zrange': [1e-7, 1e-0], 'spec': True, 'ytitle':'EFD', 'ysubtitle':'[Hz]'})
pytplot.options('erg_pwe_efd_l2_pot_Vave', opt_dict={'yrange':[-10,10], 'ytitle':'potential', 'ysubtitle':'[V]'})

# %%
data = pytplot.data_quants['merged']
arr = np.full((len(data['time']), 2), -1.0)
pytplot.store_data('pp', data={'x': data['time'], 'y': arr, 'v': [0, 1]})
# Out:
# True

# %%
from pyspedas.erg import orb
orb(trange=tr)

# %%
labels = pytplot.split_vec( orb_rmlatmlt )
pytplot.options( 'erg_orb_l2_pos_rmlatmlt_x', opt_dict={'ytitle':'L [Re]','ytitle_location':'left'} )
pytplot.options( 'erg_orb_l2_pos_rmlatmlt_y', 'ytitle', 'MLat [deg]' )
pytplot.options( 'erg_orb_l2_pos_rmlatmlt_z', 'ytitle', 'MLT [h]' )

# %%
pytplot.tplot(['merged', 'erg_pwe_hfa_l2_low_spectra_bgamma', 'erg_pwe_ofa_l2_spec_E_spectra_132', 'erg_pwe_ofa_l2_spec_B_spectra_132', 'erg_pwe_efd_l2_spec_spectra', 'EuEv', 'EuEvoff','erg_pwe_efd_l2_pot_Vave' ], xsize=12, ysize=20)
# Out:
# 02-Nov-23 21:22:13: /home/jackkooki/Document/ql_pwe/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:310: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   this_axis.set_ylim(yrange)
