# %%
import numpy as np
import pyspedas
import pytplot
import datetime as dt

# %%
tr = ['2018-09-04', '2018-09-05']

# %%
from pyspedas.erg import orb
orb(trange=tr)
# Out:
# 02-Nov-23 21:33:39: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/orb/def/2018/
# 02-Nov-23 21:33:39: File is current: erg_data/satellite/erg/orb/def/2018/erg_orb_l2_20180904_v03.cdf
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Level-2 orbit data
#
# Information about ERG orbit
#
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
#
# Contact: erg-sc-core at isee.nagoya-u.ac.jp
# **************************************************************************
# ['erg_orb_l2_pos_llr',
#  'erg_orb_l2_pos_gse',
#  'erg_orb_l2_pos_gsm',
#  'erg_orb_l2_pos_sm',
#  'erg_orb_l2_pos_rmlatmlt',
#  'erg_orb_l2_pos_eq',
#  'erg_orb_l2_pos_iono_north',
#  'erg_orb_l2_pos_iono_south',
#  'erg_orb_l2_pos_blocal',
#  'erg_orb_l2_pos_blocal_mag',
#  'erg_orb_l2_pos_beq',
#  'erg_orb_l2_pos_beq_mag',
#  'erg_orb_l2_pos_Lm',
#  'erg_orb_l2_vel_gse',
#  'erg_orb_l2_vel_gsm',
#  'erg_orb_l2_vel_sm',
#  'erg_orb_l2_spn_num',
#  'erg_orb_l2_man_prep_flag',
#  'erg_orb_l2_man_on_flag',
#  'erg_orb_l2_eclipse_flag']

# %%
# 軌道データの読み込みとIGRFモデルベースの特性周波数の変数づくり
datay = pytplot.data_quants['erg_orb_l2_pos_blocal_mag']
fce = datay / 1e9 * 1.6 * 1e-19 / (9.1093 * 1e-31) /2.0 / np.pi / 1000.0 # kHz
fce_05 = fce / 2.0 # kHz
fce_01 = fce / 10.0 # kHz

fch = fce / 1837. * 1000. # Hz

pytplot.store_data('fce', data={'x': datay['time'], 'y': fce})
pytplot.store_data('fce_05', data={'x': datay['time'], 'y': fce_05})
pytplot.store_data('fce_01', data={'x': datay['time'], 'y': fce_01})
pytplot.store_data('fch', data={'x': datay['time'], 'y': fch})
pytplot.options('fce', opt_dict={'color': 'beige', 'thick':2})
pytplot.options('fce_05', opt_dict={'color': 'magenta', 'thick':2, 'linestyle':'--'})
pytplot.options('fce_01', opt_dict={'color': 'grey', 'thick':2, 'linestyle':'--'})
pytplot.options('fch', opt_dict={'color': 'yellow', 'thick':2, 'linestyle':'--'})

# %%
# 

from pyspedas.erg import pwe_hfa
pwe_hfa(trange=tr, mode='low')
pwe_hfa(trange=tr, mode='monit')
pwe_hfa(trange=tr, mode='high')
# Out:
# 02-Nov-23 21:33:39: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/hfa/l2/spec/low/2018/09/
# 02-Nov-23 21:33:39: File is current: erg_data/satellite/erg/pwe/hfa/l2/spec/low/2018/09/erg_pwe_hfa_l2_spec_low_20180904_v01_02.cdf
# 02-Nov-23 21:33:41: erg_pwe_hfa_l2_low_spectra_eu contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:33:41: erg_pwe_hfa_l2_low_spectra_ev contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:33:41: erg_pwe_hfa_l2_low_spectra_er contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:33:41: erg_pwe_hfa_l2_low_spectra_el contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:33:41: erg_pwe_hfa_l2_low_spectra_e_ar contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:33:41: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_low_spectra_eu_ev
# 02-Nov-23 21:33:41: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_low_spectra_eu_ev
# 02-Nov-23 21:33:41: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_low_spectra_eu_ev
# 02-Nov-23 21:33:41: erg_pwe_hfa_l2_low_spectra_eu_ev does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:33:41: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_low_spectra_eu_bg
# 02-Nov-23 21:33:41: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_low_spectra_eu_bg
# 02-Nov-23 21:33:41: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_low_spectra_eu_bg
# 02-Nov-23 21:33:41: erg_pwe_hfa_l2_low_spectra_eu_bg does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:33:41: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_low_spectra_ev_bg
# 02-Nov-23 21:33:41: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_low_spectra_ev_bg
# 02-Nov-23 21:33:41: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_low_spectra_ev_bg
# 02-Nov-23 21:33:41: erg_pwe_hfa_l2_low_spectra_ev_bg does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:33:41: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/hfa/l2/spec/monit/2018/09/
# 02-Nov-23 21:33:41: File is current: erg_data/satellite/erg/pwe/hfa/l2/spec/monit/2018/09/erg_pwe_hfa_l2_spec_monit_20180904_v01_02.cdf
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Electric Field Data (HFA) Level 2 spectrum data
#
# Information about ERG PWE HFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/HFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Hfa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 02-Nov-23 21:33:41: erg_pwe_hfa_l2_monit_spectra_eu contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:33:41: erg_pwe_hfa_l2_monit_spectra_ev contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:33:41: erg_pwe_hfa_l2_monit_spectra_e_ar contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:33:41: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_monit_spectra_eu_ev
# 02-Nov-23 21:33:41: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_monit_spectra_eu_ev
# 02-Nov-23 21:33:41: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_monit_spectra_eu_ev
# 02-Nov-23 21:33:41: erg_pwe_hfa_l2_monit_spectra_eu_ev does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:33:41: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_monit_spectra_eu_bg
# 02-Nov-23 21:33:41: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_monit_spectra_eu_bg
# 02-Nov-23 21:33:41: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_monit_spectra_eu_bg
# 02-Nov-23 21:33:41: erg_pwe_hfa_l2_monit_spectra_eu_bg does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:33:41: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_monit_spectra_ev_bg
# 02-Nov-23 21:33:41: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_monit_spectra_ev_bg
# 02-Nov-23 21:33:41: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_monit_spectra_ev_bg
# 02-Nov-23 21:33:41: erg_pwe_hfa_l2_monit_spectra_ev_bg does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:33:41: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/hfa/l2/spec/high/2018/09/
# 02-Nov-23 21:33:41: File is current: erg_data/satellite/erg/pwe/hfa/l2/spec/high/2018/09/erg_pwe_hfa_l2_spec_high_20180904_v01_02.cdf
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Electric Field Data (HFA) Level 2 spectrum data
#
# Information about ERG PWE HFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/HFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Hfa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 02-Nov-23 21:33:43: erg_pwe_hfa_l2_high_spectra_eu contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:33:43: erg_pwe_hfa_l2_high_spectra_ev contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:33:43: erg_pwe_hfa_l2_high_spectra_er contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:33:43: erg_pwe_hfa_l2_high_spectra_el contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:33:43: erg_pwe_hfa_l2_high_spectra_e_mix contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:33:43: erg_pwe_hfa_l2_high_spectra_e_ar contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 02-Nov-23 21:33:43: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_high_spectra_eu_ev
# 02-Nov-23 21:33:43: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_high_spectra_eu_ev
# 02-Nov-23 21:33:43: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_high_spectra_eu_ev
# 02-Nov-23 21:33:43: erg_pwe_hfa_l2_high_spectra_eu_ev does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:33:43: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_high_spectra_eu_bg
# 02-Nov-23 21:33:43: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_high_spectra_eu_bg
# 02-Nov-23 21:33:43: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_high_spectra_eu_bg
# 02-Nov-23 21:33:43: erg_pwe_hfa_l2_high_spectra_eu_bg does not contain coordinates for spectrogram plotting.  Continuing...
# 02-Nov-23 21:33:44: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_high_spectra_ev_bg
# 02-Nov-23 21:33:44: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_high_spectra_ev_bg
# 02-Nov-23 21:33:44: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_high_spectra_ev_bg
# 02-Nov-23 21:33:44: erg_pwe_hfa_l2_high_spectra_ev_bg does not contain coordinates for spectrogram plotting.  Continuing...
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Electric Field Data (HFA) Level 2 spectrum data
#
# Information about ERG PWE HFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/HFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Hfa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# ['erg_pwe_hfa_l2_high_Epoch',
#  'erg_pwe_hfa_l2_high_spectra_eu',
#  'erg_pwe_hfa_l2_high_spectra_ev',
#  'erg_pwe_hfa_l2_high_spectra_bgamma',
#  'erg_pwe_hfa_l2_high_spectra_esum',
#  'erg_pwe_hfa_l2_high_spectra_er',
#  'erg_pwe_hfa_l2_high_spectra_el',
#  'erg_pwe_hfa_l2_high_spectra_e_mix',
#  'erg_pwe_hfa_l2_high_spectra_e_ar',
#  'erg_pwe_hfa_l2_high_spectra_eu_ev',
#  'erg_pwe_hfa_l2_high_spectra_eu_bg',
#  'erg_pwe_hfa_l2_high_spectra_ev_bg',
#  'erg_pwe_hfa_l2_high_quality_flag']

# %%
timelow = pytplot.data_quants['erg_pwe_hfa_l2_low_spectra_e_mix']['time']
low = pytplot.data_quants['erg_pwe_hfa_l2_low_spectra_e_mix']
timemonit = pytplot.data_quants['erg_pwe_hfa_l2_monit_spectra_e_mix']['time']
monit = pytplot.data_quants['erg_pwe_hfa_l2_monit_spectra_e_mix']
timelow = timelow.to_numpy()
timemonit = timemonit.to_numpy()
len_v_dim = len(pytplot.data_quants['erg_pwe_hfa_l2_monit_spectra_e_mix']['v_dim'])
v_dim = pytplot.data_quants['erg_pwe_hfa_l2_monit_spectra_e_mix']['v_dim']
timemerged = np.sort(np.hstack((timelow, timemonit)))
len_v_dim = len(pytplot.data_quants['erg_pwe_hfa_l2_monit_spectra_e_mix']['v_dim'])
merged_data = np.zeros((len(timemerged), len_v_dim))

# 'low' データを 'timelow' に対応する位置にコピー
for i, timestamp in enumerate(timelow):
    index = np.where(timemerged == timestamp)[0]
    merged_data[index] = low[i]

# 'omit' データを 'timeomit' に対応する位置にコピー
for i, timestamp in enumerate(timemonit):
    #mask = timemerged == timestamp  # 'timestamp' と一致する場所を示すブール値の配列を作成
    index = np.where(timemerged == timestamp)[0]
    merged_data[index] = monit[i]
pytplot.store_data('merged', data={'x': timemerged, 'y': merged_data, 'v': v_dim})
# Out:
# True

# %%
from pyspedas.erg import pwe_ofa
pwe_ofa(trange=tr)
# Out:
# 02-Nov-23 21:33:45: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2018/09/
# 02-Nov-23 21:33:46: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2018/09/erg_pwe_ofa_l2_spec_20180904_v02_03.cdf
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/OFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Ofa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# ['erg_pwe_ofa_l2_spec_epoch_e132',
#  'erg_pwe_ofa_l2_spec_E_spectra_132',
#  'erg_pwe_ofa_l2_spec_quality_flag_e132',
#  'erg_pwe_ofa_l2_spec_epoch_b132',
#  'erg_pwe_ofa_l2_spec_B_spectra_132',
#  'erg_pwe_ofa_l2_spec_quality_flag_b132']

# %%
from pyspedas.erg import pwe_efd
pwe_efd(trange=tr, datatype='spec')
pwe_efd(trange=tr, datatype='E_spin')
pwe_efd(trange=tr, datatype='pot')
# Out:
# 02-Nov-23 21:34:23: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/efd/l2/spec/2018/09/
# 02-Nov-23 21:34:23: File is current: erg_data/satellite/erg/pwe/efd/l2/spec/2018/09/erg_pwe_efd_l2_spec_20180904_v02_02.cdf
# 02-Nov-23 21:34:23: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/efd/l2/E_spin/2018/09/
# 02-Nov-23 21:34:24: No links matching pattern erg_pwe_efd_l2_E_spin_20180904_v??_??.cdf found at remote index https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/efd/l2/E_spin/2018/09/
# 02-Nov-23 21:34:24: erg_pwe_efd_l2_E_spin_Eu_dsi is currently not in pytplot.
# 02-Nov-23 21:34:24: erg_pwe_efd_l2_E_spin_Eu_dsi is currently not in pytplot.
# 02-Nov-23 21:34:24: The name erg_pwe_efd_l2_E_spin_Eu_dsi is currently not in pytplot
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Electric Field Data (EFD) Level 2 spectrum data
#
# Information about ERG PWE EFD
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/EFD: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Efd
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/jackkooki/Document/ql_pwe/src/py_save.ipynb Cell 9 line 3
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jackkooki/Document/ql_pwe/src/py_save.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from pyspedas.erg import pwe_efd
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jackkooki/Document/ql_pwe/src/py_save.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> pwe_efd(trange=tr, datatype='spec')
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jackkooki/Document/ql_pwe/src/py_save.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> pwe_efd(trange=tr, datatype='E_spin')
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jackkooki/Document/ql_pwe/src/py_save.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> pwe_efd(trange=tr, datatype='pot')
#
# File ~/Document/ql_pwe/.venv/lib/python3.10/site-packages/pyspedas/erg/satellite/erg/pwe/pwe_efd.py:161, in pwe_efd(trange, datatype, level, suffix, coord, get_support_data, varformat, varnames, downloadonly, notplot, no_update, uname, passwd, time_clip, ror)
#     158 # ylim settings because pytplot.timespan() doesn't affect in ylim.
#     159 # May be it will be no need in future.
#     160 get_data_vars = get_data(t_plot_name)
# --> 161 if get_data_vars[0][0] < time_min_max[0]:
#     162     min_time_index = np.where(
#     163         (get_data_vars[0] <= time_min_max[0]))[0][-1]
#     164 else:
#
# TypeError: 'NoneType' object is not subscriptable

# %%
Eux = pytplot.data_quants['erg_pwe_efd_l2_E_spin_Eu_dsi'][:,0]
Euy = pytplot.data_quants['erg_pwe_efd_l2_E_spin_Eu_dsi'][:,1]
Evx = pytplot.data_quants['erg_pwe_efd_l2_E_spin_Ev_dsi'][:,0]
Evy = pytplot.data_quants['erg_pwe_efd_l2_E_spin_Ev_dsi'][:,1]
Euoff = pytplot.data_quants['erg_pwe_efd_l2_E_spin_Eu_offset']
Evoff = pytplot.data_quants['erg_pwe_efd_l2_E_spin_Ev_offset']
EuEvoff = np.zeros((len(Euoff), 2))
EuEvoff[:,0] = Euoff
EuEvoff[:,1] = Evoff
Eu = np.sqrt(Eux**2 + Euy**2)
Ev = np.sqrt(Evx**2 + Evy**2)
EuEv = np.zeros((len(Eu), 2))
EuEv[:,0] = Eu
EuEv[:,1] = Ev
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/jackkooki/Document/ql_pwe/src/py_save.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jackkooki/Document/ql_pwe/src/py_save.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> Eux = pytplot.data_quants['erg_pwe_efd_l2_E_spin_Eu_dsi'][:,0]
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jackkooki/Document/ql_pwe/src/py_save.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> Euy = pytplot.data_quants['erg_pwe_efd_l2_E_spin_Eu_dsi'][:,1]
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jackkooki/Document/ql_pwe/src/py_save.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> Evx = pytplot.data_quants['erg_pwe_efd_l2_E_spin_Ev_dsi'][:,0]
#
# KeyError: 'erg_pwe_efd_l2_E_spin_Eu_dsi'

# %%
pytplot.store_data('EuEv', data={'x': pytplot.data_quants['erg_pwe_efd_l2_E_spin_Eu_dsi']['time'], 'y': EuEv})
pytplot.store_data('EuEvoff', data={'x': pytplot.data_quants['erg_pwe_efd_l2_E_spin_Eu_dsi']['time'], 'y': EuEvoff})
pytplot.options('EuEv', opt_dict={'legend_names': ['u', 'v'], 'yrange': [ 0, 10], 'ytitle':'EFD amplitude', 'ysubtitle':'[mV/m]'})
pytplot.options('EuEvoff', opt_dict={'legend_names': ['u', 'v'], 'yrange': [ -10,10], 'ytitle':'EFD offset', 'ysubtitle':'[mV/m]'})

# %%
data = pytplot.data_quants['merged']
arr = np.full((len(data['time']), 2), -1.0)
pytplot.store_data('pp', data={'x': data['time'], 'y': arr, 'v': [0, 1]})
# Out:
# True

# %%
from pyspedas.erg import orb
orb(trange=tr)
# Out:
# 02-Nov-23 21:26:12: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/orb/def/2018/
# 02-Nov-23 21:26:12: File is current: erg_data/satellite/erg/orb/def/2018/erg_orb_l2_20181008_v03.cdf
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Level-2 orbit data
#
# Information about ERG orbit
#
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
#
# Contact: erg-sc-core at isee.nagoya-u.ac.jp
# **************************************************************************
# ['erg_orb_l2_pos_llr',
#  'erg_orb_l2_pos_gse',
#  'erg_orb_l2_pos_gsm',
#  'erg_orb_l2_pos_sm',
#  'erg_orb_l2_pos_rmlatmlt',
#  'erg_orb_l2_pos_eq',
#  'erg_orb_l2_pos_iono_north',
#  'erg_orb_l2_pos_iono_south',
#  'erg_orb_l2_pos_blocal',
#  'erg_orb_l2_pos_blocal_mag',
#  'erg_orb_l2_pos_beq',
#  'erg_orb_l2_pos_beq_mag',
#  'erg_orb_l2_pos_Lm',
#  'erg_orb_l2_vel_gse',
#  'erg_orb_l2_vel_gsm',
#  'erg_orb_l2_vel_sm',
#  'erg_orb_l2_spn_num',
#  'erg_orb_l2_man_prep_flag',
#  'erg_orb_l2_man_on_flag',
#  'erg_orb_l2_eclipse_flag']

# %%
labels = pytplot.split_vec( 'erg_orb_l2_pos_rmlatmlt' )
pytplot.options( 'erg_orb_l2_pos_rmlatmlt_x', opt_dict={'ytitle':'L [Re]','ytitle_location':'left'} )
pytplot.options( 'erg_orb_l2_pos_rmlatmlt_y', 'ytitle', 'MLat [deg]' )
pytplot.options( 'erg_orb_l2_pos_rmlatmlt_z', 'ytitle', 'MLT [h]' )
pytplot.options('merged', opt_dict={'zlog': True, 'ylog': True, 'yrange': [1e-0, 1e4], 'zrange': [1e-10, 1e-3], 'spec': True, 'ytitle':'HFA Emix'})
pytplot.options( 'erg_pwe_hfa_l2_low_spectra_bgamma', opt_dict={ 'ytitle':'HFA(Bz)', 'ysubtitle':'[kHz]'})
pytplot.options( 'erg_pwe_ofa_l2_spec_E_spectra_132' , opt_dict={'zlog': True, 'ylog': True, 'zrange': [1e-9, 1e-2], 'spec': True, 'ytitle':'OFA-E', 'ysubtitle':'[kHz]'})
pytplot.options( 'erg_pwe_ofa_l2_spec_B_spectra_132' , opt_dict={'zlog': True, 'ylog': True, 'zrange': [1e-4, 1e2], 'spec': True, 'ytitle':'OFA-B', 'ysubtitle':'[kHz]'})
pytplot.options('erg_pwe_efd_l2_spec_spectra', opt_dict={'zlog': True, 'ylog': 0, 'zrange': [1e-7, 1e-0], 'spec': True, 'ytitle':'EFD', 'ysubtitle':'[Hz]'})
pytplot.options('erg_pwe_efd_l2_pot_Vave', opt_dict={'yrange':[-10,10], 'ytitle':'potential', 'ysubtitle':'[V]'})

# %%
pytplot.tplot(['merged', 'erg_pwe_hfa_l2_low_spectra_bgamma', 'erg_pwe_ofa_l2_spec_E_spectra_132', 'erg_pwe_ofa_l2_spec_B_spectra_132', 'erg_pwe_efd_l2_spec_spectra', 'EuEv', 'EuEvoff','erg_pwe_efd_l2_pot_Vave' ], xsize=12, ysize=20, var_label=labels)
